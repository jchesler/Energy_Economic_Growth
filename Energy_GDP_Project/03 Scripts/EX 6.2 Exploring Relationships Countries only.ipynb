# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
#create path
path = r'C:\Users\jacob\Documents\Data Analytics\Data Immersion\Achievement 6\Energy_GDP_Project'

# %%
#import merged inner data
df = pd.read_csv(os.path.join(path, '02 data', 'prepared data', 'energy_gdp_merged_inner_countries.csv'))

# %%
#check output
df.head()
# Out:
#        country  year       combined_key   ea_%_pop  %_energy_nuclear  \
# 0  Afghanistan  2000  Afghanistan, 2000   4.446891               0.0
# 1  Afghanistan  2001  Afghanistan, 2001   9.294527               0.0
# 2  Afghanistan  2002  Afghanistan, 2002  14.133616               0.0
# 3  Afghanistan  2003  Afghanistan, 2003  18.971165               0.0
# 4  Afghanistan  2004  Afghanistan, 2004  23.814182               0.0
#
#    %_energy_renewables  %_energy_fossil_fuels         gdp
# 0                  0.0                    0.0  183.532775
# 1                  0.0                    0.0  183.532775
# 2                  0.0                    0.0  183.532775
# 3                  0.0                    0.0  200.462376
# 4                  0.0                    0.0  221.657662

# %%
#check descriptive analysis
df.describe()
# Out:
#               year     ea_%_pop  %_energy_nuclear  %_energy_renewables  \
# count  4730.000000  4730.000000       4730.000000          4730.000000
# mean   2003.887315    80.461152          4.368226             1.980537
# std       7.055844    30.087069         13.008783             5.284833
# min    1990.000000     0.533899          0.000000             0.000000
# 25%    1998.000000    69.710360          0.000000             0.000000
# 50%    2004.000000    99.000000          0.000000             0.000000
# 75%    2010.000000   100.000000          0.000000             1.051397
# max    2015.000000   100.000000         87.986221            65.443742
#
#        %_energy_fossil_fuels            gdp
# count            4730.000000    4730.000000
# mean               39.638463   13941.936532
# std                39.220871   21058.857897
# min                 0.000000     110.460875
# 25%                 0.000000    1323.236545
# 50%                32.016672    4832.516478
# ...

# %%
#create a subset for analysis
df_subset = df[['ea_%_pop', '%_energy_nuclear', '%_energy_renewables', '%_energy_fossil_fuels', 'gdp']]

# %%
#check output
df_subset.head()
# Out:
#     ea_%_pop  %_energy_nuclear  %_energy_renewables  %_energy_fossil_fuels  \
# 0   4.446891               0.0                  0.0                    0.0
# 1   9.294527               0.0                  0.0                    0.0
# 2  14.133616               0.0                  0.0                    0.0
# 3  18.971165               0.0                  0.0                    0.0
# 4  23.814182               0.0                  0.0                    0.0
#
#           gdp
# 0  183.532775
# 1  183.532775
# 2  183.532775
# 3  200.462376
# 4  221.657662

# %%
#create a matric heatmap using matplot
f = plt.figure(figsize=(8, 8))
plt.matshow(df_subset.corr(), fignum=f.number)
plt.xticks(range(df_subset.shape[1]), df_subset.columns, fontsize=14, rotation = 45)
plt.yticks(range(df_subset.shape[1]), df_subset.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
#create a heatmap using seaborn

f,ax = plt.subplots(figsize=(8,8))

corr = sns.heatmap(df_subset.corr(), annot = True, cmap='viridis', fmt='.2f', linewidths =.5, ax = ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.title('Correlation Matrix', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# For these coefficients in each sqaure represents the correlation between the two varialbes. the large the coefficient, the stronger the positive correlation between the two variables. Some values are negative, which represent an inverse correlation.
#
# In this chart the strongest correlation is between percent of the population that has access to energy and the gdp per capita. In other words, as the percent of people have access to electricity increases, so does the gdp per capita and vice versa.

# %%
#create scatter plot between gdp and ea_%_pop
sns.lmplot(x = 'ea_%_pop', y = 'gdp', data = df)
# Out:
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#create scatter plot between gdp and ea_%_pop
sns.lmplot(x = 'ea_%_pop', y = '%_energy_nuclear', data = df)
# Out:
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# These two charts show that the disrobution of the data has an interesting distrobution. It is clear that as a country has more access to electricty they are more likely to have a higher gdp and more energy from nuclear sources.
#
# There is a lot of data grouped at the bottom, and it may be benefical to look at these charts without the higher values gdp

# %%
#create pair plot with dataframe subset
pair = sns.pairplot(df_subset)
# Out:
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
#create a pair plot with full dataset
pair_2 = sns.pairplot(df)
# Out:
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# This data looks pretty spread out in most of hte categories. An interesting is that a lot of areas have pretty distinct cut off lines within them.
#
# (Year and ea_%_pop) - this relationship covers almost the entire graph. This is telling us that each year from 1990 through 2015 there is a wide spread of access to electricity year to year.
#
# (Year and %_energy_nuclear) - This relationship covers almost the entire graph, but it has a gap between 60% and 80%. This graph suggests that nuclear energy stays pretty consisent across time, and it appears that some countries are well above others. The top portion of the graph does have a slight negative trend.
#
# (Year and %_energy_renewables) - From 1990 - 2015 there is a steady amount of countries that have 10 or less percent of their energy production from renewables. the density of countries between 10-30% begins to increas around 1995 and 2000. There is a slight trend upwards close to 2015  where a few countries have pushed up to almost 50% of energy from renewables.
#
# (Year and Fossil_Fuels). This chart fills the entire frame and shows that there is a wide spread in energy from fossil fuels from year to year, ranging from 0% to 100%
#
# (Year and GDP) - There is a dense grouping of GDP 50000 and belwo from the year 1990 to about 2005. In 2005 there begin to be countries that increase rapidly away from the dense group, and the dense grouping does increase to around a GDP of 100000. There is also a steady grouping just under 100000 GDP all the way from 1990 to 2015.
#
# (ea_%_pop and energy_nuclear) - there is a very distinct flipped L shaped that has been created. So There does appear to be an increase in enery from nuclear when a populations electricty access reaches about 50%. And while there is still a wide range of energy from nuclear for countries with populaitons that have 100% access to electricty. It can be safely stated that the countries with the most energy from electrcity have at least a 75% of its population having access to electricity. Further, the country with the largest percent of their energy from nuclear, is a country that has a population with all of its population having access to electricity.
#
# (ea_%_pop and energy_renewables) - this relationship is a little more sparatic, meaning that it doesn't have an apparent trend of data. There are some countries with rather low percentage of the population that has access to electricty, but they still have aroudn 20% of their energy from renewables. Just like about though we can be safe in saying that the country with the largest percent of enrgy from renewables has a population where 100 percent of its people have access to electrcity.
#
# (ea_%_pop and fossil_fuels) - because the spread of fossil fuels is so spread across the board, this data is not difference. there is not apparent trend in the data.
#
# (ea_%_pop and gdp) this relationship is very similar to (ea_%_pop and energy_nuclear). GDP is pretty constant until about 75% of the population has access to electricty. The range of GDP at 100% of access to electricity is wide. But it can be stated that the country with the highest GDP will have 100% of its population with access to electricity.
#
# (energy_nuclear and fossil fuels/gdp/renewables) all have very similar negative slop relationships. Meaing as energy from fossil fuels increases, they all decrease. one interesting note is that in the enery from fossil fuels chart, energy from fossil fuels hardly ever reaches zero, even when energy from nuclear is at its highest point.
#
# the relationships that I think would be interesting to explore would be comparing year to gdp, renewables, and nuclear, there seems to be interesting trends within those areas.
#
# I also want to look more into electricty access relative to fossil fuels. I especially think this would be interesting if the data was filtered more so that I only looked at countries that didn't have 100% access and countries taht didn't have 0% access. I think the growth in the deveopling areas would be really interesting.
#
# in fact, i think that would be the most interesting part of the data.

# %%
#create a categorical histogram plot
sns.histplot(df['gdp'], bins = 25, kde = True)
# Out:
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='gdp', ylabel='Count'>

# %%
sns.histplot(df['ea_%_pop'], bins = 20, kde = True)
# Out:
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='ea_%_pop', ylabel='Count'>

# %%
sns.histplot(df['%_energy_fossil_fuels'], bins = 20, kde = True)
# Out:
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='%_energy_fossil_fuels', ylabel='Count'>

# %%
sns.histplot(df['%_energy_nuclear'], bins = 20, kde = True)
# Out:
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='%_energy_nuclear', ylabel='Count'>

# %%
sns.histplot(df['%_energy_renewables'], bins = 20, kde = True)
# Out:
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\users\jacob\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='%_energy_renewables', ylabel='Count'>

# %% [markdown]
# These histograms all show that the highend of some groups and the low end of some groups could be removed to get a better image, but that also wouldn't capture the full picture of the data.

# %% [markdown]
# Questions with Answers
# -The strongest correlation is between GDP and access to electricity, but this correlation is only moderately strong
# -There are weak positive correlations between GDP per capita and energy from nuclear and renewable sources.
#
# Hypotheses
# As a country's GDP increases, the percent of the population that has access to electricity will increase
#
# As a country's GDP increases, the percent of energy production from nuclear sources will increase.
# A
# As a country's GDP increases, the percent of energy production from renewable sources will increase.
#
# As a country's GDP increases, the percent of energy production from fossil fuels sources will decrease.
#
# As time increases, a country's GDP will increase
#
# As time increases, the percent of the population who has access to electricity in developing countries (countries who don't already have 100% access to electricity) will increase.
