# %%
import pandas as pd
import numpy as np
import os
import geopandas as gpd

# %%
#import geojson file
gdf  = gpd.read_file(r"C:\Users\jacob\Documents\Data Analytics\Data Immersion\Achievement 6\Energy_GDP_Project\02 Data\Prepared Data\countries_updated.geojson")

# %%
#check output
gdf.head()
# Out:
#          ADMIN ISO_A3                                           geometry
# 0        Aruba    ABW  POLYGON ((-69.99694 12.57758, -69.93639 12.531...
# 1  Afghanistan    AFG  POLYGON ((71.04980 38.40866, 71.05714 38.40903...
# 2       Angola    AGO  MULTIPOLYGON (((11.73752 -16.69258, 11.73851 -...
# 3     Anguilla    AIA  MULTIPOLYGON (((-63.03767 18.21296, -63.09952 ...
# 4      Albania    ALB  POLYGON ((19.74777 42.57890, 19.74601 42.57993...

# %%
gdf.head(700)
# Out:
#             ADMIN ISO_A3                                           geometry
# 0           Aruba    ABW  POLYGON ((-69.99694 12.57758, -69.93639 12.531...
# 1     Afghanistan    AFG  POLYGON ((71.04980 38.40866, 71.05714 38.40903...
# 2          Angola    AGO  MULTIPOLYGON (((11.73752 -16.69258, 11.73851 -...
# 3        Anguilla    AIA  MULTIPOLYGON (((-63.03767 18.21296, -63.09952 ...
# 4         Albania    ALB  POLYGON ((19.74777 42.57890, 19.74601 42.57993...
# ..            ...    ...                                                ...
# 250         Samoa    WSM  MULTIPOLYGON (((-171.57002 -13.93816, -171.564...
# 251   Yemen, Rep.    YEM  MULTIPOLYGON (((53.30824 12.11839, 53.31027 12...
# 252  South Africa    ZAF  MULTIPOLYGON (((37.86378 -46.94085, 37.83644 -...
# 253        Zambia    ZMB  POLYGON ((31.11984 -8.61663, 31.14102 -8.60619...
# 254      Zimbabwe    ZWE  POLYGON ((30.01065 -15.64623, 30.05024 -15.640...
#
# [255 rows x 3 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
gdf.head(255)
# Out:
#                                         ADMIN ISO_A3  \
# 0                                       Aruba    ABW
# 1                                 Afghanistan    AFG
# 2                                      Angola    AGO
# 3                                    Anguilla    AIA
# 4                                     Albania    ALB
# 5                                       Aland    ALA
# 6                                     Andorra    AND
# 7                        United Arab Emirates    ARE
# 8                                   Argentina    ARG
# 9                                     Armenia    ARM
# 10                             American Samoa    ASM
# 11                                 Antarctica    ATA
# 12                Ashmore and Cartier Islands    -99
# 13        French Southern and Antarctic Lands    ATF
# 14                        Antigua and Barbuda    ATG
# 15                                  Australia    AUS
# 16                                    Austria    AUT
# ...
