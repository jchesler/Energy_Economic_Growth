# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#create path
path = r'C:\Users\jacob\Documents\Data Analytics\Data Immersion\Achievement 6\Energy_GDP_Project'

# %%
#import energy from nuclear (nuc) data
nuc = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'energy_from_nuclear.csv'))

# %%
#check output
nuc.head()
# Out:
#        country  year       combined key  %_energy_from_nuclear
# 0  Afghanistan  1990  Afghanistan, 1990                    NaN
# 1  Afghanistan  1991  Afghanistan, 1991                    NaN
# 2  Afghanistan  1992  Afghanistan, 1992                    NaN
# 3  Afghanistan  1993  Afghanistan, 1993                    NaN
# 4  Afghanistan  1994  Afghanistan, 1994                    NaN

# %%
nuc.shape
# Out:
# (6916, 4)

# %%
#change % energy from nuclear to % energy_nuclear
nuc.rename(columns = {'%_energy_from_nuclear' : '%_energy_nuclear'}, inplace = True)

# %%
#check output
nuc.head()
# Out:
#        country  year       combined key  %_energy_nuclear
# 0  Afghanistan  1990  Afghanistan, 1990               NaN
# 1  Afghanistan  1991  Afghanistan, 1991               NaN
# 2  Afghanistan  1992  Afghanistan, 1992               NaN
# 3  Afghanistan  1993  Afghanistan, 1993               NaN
# 4  Afghanistan  1994  Afghanistan, 1994               NaN

# %%
#check for missing values
nuc.isnull().sum()
# Out:
# country                0
# year                   0
# combined key           0
# %_energy_nuclear    2282
# dtype: int64

# %%
#check for duplicates
nuc.duplicated().value_counts()
# Out:
# False    6916
# Name: count, dtype: int64

# %%
#descriptive analysis
nuc.describe()
# Out:
#               year  %_energy_nuclear
# count  6916.000000       4634.000000
# mean   2002.500000          6.172183
# std       7.500542         13.635725
# min    1990.000000          0.000000
# 25%    1996.000000          0.000000
# 50%    2002.500000          0.000000
# 75%    2009.000000          3.666252
# max    2015.000000         87.986221

# %% [markdown]
# There are no duplicate values, but there are 2282 missing values in the % of energy produced from nuclear column. this could be due to the fact that the 75% of the entries have less than 4% of their energy from nuclear. Because of this I will imput 0 for all of the missing values so that we don't lose that data.

# %%
#group data by nuclear data to make it easier to find missing data
nuc_grouped = nuc.groupby('country', as_index = False)['%_energy_nuclear'].sum()

# %%
#check output
nuc_grouped
# Out:
#                          country  %_energy_nuclear
# 0                    Afghanistan          0.000000
# 1    Africa Eastern and Southern         98.466993
# 2     Africa Western and Central          0.000000
# 3                        Albania          0.000000
# 4                        Algeria          0.000000
# ..                           ...               ...
# 261           West Bank and Gaza          0.000000
# 262                        World        388.379554
# 263                  Yemen, Rep.          0.000000
# 264                       Zambia          0.000000
# 265                     Zimbabwe          0.000000
#
# [266 rows x 2 columns]

# %%
#create a flag for whether or not the weighted average or zero needs to be imputed for missing values
nuc_grouped.loc[nuc_grouped['%_energy_nuclear'] > 0, 'imputed_value'] = 'weighted_avg'
nuc_grouped.loc[nuc_grouped['%_energy_nuclear'] == 0, 'imputed_value'] = 'zero'
# Out:
# C:\Users\jacob\AppData\Local\Temp\ipykernel_9004\743190894.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'weighted_avg' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   nuc_grouped.loc[nuc_grouped['%_energy_nuclear'] > 0, 'imputed_value'] = 'weighted_avg'

# %%
#check flag column
nuc_grouped
# Out:
#                          country  %_energy_nuclear imputed_value
# 0                    Afghanistan          0.000000          zero
# 1    Africa Eastern and Southern         98.466993  weighted_avg
# 2     Africa Western and Central          0.000000          zero
# 3                        Albania          0.000000          zero
# 4                        Algeria          0.000000          zero
# ..                           ...               ...           ...
# 261           West Bank and Gaza          0.000000          zero
# 262                        World        388.379554  weighted_avg
# 263                  Yemen, Rep.          0.000000          zero
# 264                       Zambia          0.000000          zero
# 265                     Zimbabwe          0.000000          zero
#
# [266 rows x 3 columns]

# %%
#create a new data fram that creates a list for either wieghted average or zero imputations
nuc_grouped_2 = nuc_grouped.groupby('imputed_value')['country'].agg(list).reset_index()

# %%
nuc_grouped_2
# Out:
#   imputed_value                                            country
# 0  weighted_avg  [Africa Eastern and Southern, Argentina, Armen...
# 1          zero  [Afghanistan, Africa Western and Central, Alba...

# %%
group1_countries = nuc_grouped_2.loc[nuc_grouped_2['imputed_value'] == 'weighted_avg', 'country'].values[0]
group2_countries = nuc_grouped_2.loc[nuc_grouped_2['imputed_value'] == 'zero', 'country'].values[0]

# %%
#list for countries that need weighted averages imputed
group1_countries
# Out:
# ['Africa Eastern and Southern',
#  'Argentina',
#  'Armenia',
#  'Belgium',
#  'Brazil',
#  'Bulgaria',
#  'Canada',
#  'Central Europe and the Baltics',
#  'China',
#  'Czechia',
#  'Early-demographic dividend',
#  'East Asia & Pacific',
#  'East Asia & Pacific (IDA & IBRD countries)',
#  'East Asia & Pacific (excluding high income)',
#  'Euro area',
#  'Europe & Central Asia',
#  'Europe & Central Asia (IDA & IBRD countries)',
#  'Europe & Central Asia (excluding high income)',
#  'European Union',
#  'Finland',
#  'Fragile and conflict affected situations',
#  'France',
#  'Germany',
#  'High income',
#  'Hungary',
#  'IBRD only',
#  'IDA & IBRD total',
#  'IDA blend',
#  'IDA total',
#  'India',
#  'Iran, Islamic Rep.',
#  'Japan',
#  'Korea, Rep.',
#  'Late-demographic dividend',
#  'Latin America & Caribbean',
#  'Latin America & Caribbean (excluding high income)',
#  'Latin America & the Caribbean (IDA & IBRD countries)',
#  'Lithuania',
#  'Low & middle income',
#  'Lower middle income',
#  'Mexico',
#  'Middle East & North Africa',
#  'Middle East & North Africa (IDA & IBRD countries)',
#  'Middle East & North Africa (excluding high income)',
#  'Middle income',
#  'Netherlands',
#  'North America',
#  'OECD members',
#  'Pakistan',
#  'Post-demographic dividend',
#  'Romania',
#  'Russian Federation',
#  'Slovak Republic',
#  'Slovenia',
#  'South Africa',
#  'South Asia',
#  'South Asia (IDA & IBRD)',
#  'Spain',
#  'Sub-Saharan Africa',
#  'Sub-Saharan Africa (IDA & IBRD countries)',
#  'Sub-Saharan Africa (excluding high income)',
#  'Sweden',
#  'Switzerland',
#  'Ukraine',
#  'United Kingdom',
#  'United States',
#  'Upper middle income',
#  'World']

# %%
#list of countries that need zero imputed for missing values
group2_countries
# Out:
# ['Afghanistan',
#  'Africa Western and Central',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Arab World',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Caribbean small states',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt, Arab Rep.',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Faroe Islands',
#  'Fiji',
#  'French Polynesia',
#  'Gabon',
#  'Gambia, The',
#  'Georgia',
#  'Ghana',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guam',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Heavily indebted poor countries (HIPC)',
#  'Honduras',
#  'Hong Kong SAR, China',
#  'IDA only',
#  'Iceland',
#  'Indonesia',
#  'Iraq',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  "Korea, Dem. People's Rep.",
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyz Republic',
#  'Lao PDR',
#  'Latvia',
#  'Least developed countries: UN classification',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Liechtenstein',
#  'Low income',
#  'Luxembourg',
#  'Macao SAR, China',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Marshall Islands',
#  'Mauritania',
#  'Mauritius',
#  'Micronesia, Fed. Sts.',
#  'Moldova',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'New Caledonia',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'North Macedonia',
#  'Northern Mariana Islands',
#  'Norway',
#  'Not classified',
#  'Oman',
#  'Other small states',
#  'Pacific island small states',
#  'Palau',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Pre-demographic dividend',
#  'Puerto Rico',
#  'Qatar',
#  'Rwanda',
#  'Samoa',
#  'San Marino',
#  'Sao Tome and Principe',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Sint Maarten (Dutch part)',
#  'Small states',
#  'Solomon Islands',
#  'Somalia',
#  'South Sudan',
#  'Sri Lanka',
#  'St. Kitts and Nevis',
#  'St. Lucia',
#  'St. Martin (French part)',
#  'St. Vincent and the Grenadines',
#  'Sudan',
#  'Suriname',
#  'Syrian Arab Republic',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Timor-Leste',
#  'Togo',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkiye',
#  'Turkmenistan',
#  'Turks and Caicos Islands',
#  'Tuvalu',
#  'Uganda',
#  'United Arab Emirates',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Venezuela, RB',
#  'Viet Nam',
#  'Virgin Islands (U.S.)',
#  'West Bank and Gaza',
#  'Yemen, Rep.',
#  'Zambia',
#  'Zimbabwe']

# %%
nuc_weight = nuc[nuc['country'].isin(group1_countries)]

# %%
#check number of countries in weighted average list
nuc_weight['country'].nunique()
# Out:
# 68

# %%
nuc_zero = nuc[nuc['country'].isin(group2_countries)]

# %%
#check number of counties in zero list
nuc_zero['country'].nunique()
# Out:
# 198

# %%
198 + 68
# Out:
# 266

# %%
#check for missing vlaues
nuc_zero.isnull().sum()
# Out:
# country                0
# year                   0
# combined key           0
# %_energy_nuclear    2255
# dtype: int64

# %%
#impute zero for missing values in in this list
nuc_zero_imputed = nuc_zero.fillna(0)

# %%
nuc_zero_imputed.isnull().sum()
# Out:
# country             0
# year                0
# combined key        0
# %_energy_nuclear    0
# dtype: int64

# %%
nuc_zero_imputed
# Out:
#           country  year       combined key  %_energy_nuclear
# 0     Afghanistan  1990  Afghanistan, 1990               0.0
# 1     Afghanistan  1991  Afghanistan, 1991               0.0
# 2     Afghanistan  1992  Afghanistan, 1992               0.0
# 3     Afghanistan  1993  Afghanistan, 1993               0.0
# 4     Afghanistan  1994  Afghanistan, 1994               0.0
# ...           ...   ...                ...               ...
# 6911     Zimbabwe  2011     Zimbabwe, 2011               0.0
# 6912     Zimbabwe  2012     Zimbabwe, 2012               0.0
# 6913     Zimbabwe  2013     Zimbabwe, 2013               0.0
# 6914     Zimbabwe  2014     Zimbabwe, 2014               0.0
# 6915     Zimbabwe  2015     Zimbabwe, 2015               0.0
#
# [5148 rows x 4 columns]

# %%
nuc_zero_imputed.head()
# Out:
#        country  year       combined key  %_energy_nuclear
# 0  Afghanistan  1990  Afghanistan, 1990               0.0
# 1  Afghanistan  1991  Afghanistan, 1991               0.0
# 2  Afghanistan  1992  Afghanistan, 1992               0.0
# 3  Afghanistan  1993  Afghanistan, 1993               0.0
# 4  Afghanistan  1994  Afghanistan, 1994               0.0

# %%
nuc_weight.head(30)
# Out:
#                          country  year                       combined key  \
# 26   Africa Eastern and Southern  1990  Africa Eastern and Southern, 1990
# 27   Africa Eastern and Southern  1991  Africa Eastern and Southern, 1991
# 28   Africa Eastern and Southern  1992  Africa Eastern and Southern, 1992
# 29   Africa Eastern and Southern  1993  Africa Eastern and Southern, 1993
# 30   Africa Eastern and Southern  1994  Africa Eastern and Southern, 1994
# 31   Africa Eastern and Southern  1995  Africa Eastern and Southern, 1995
# 32   Africa Eastern and Southern  1996  Africa Eastern and Southern, 1996
# 33   Africa Eastern and Southern  1997  Africa Eastern and Southern, 1997
# 34   Africa Eastern and Southern  1998  Africa Eastern and Southern, 1998
# 35   Africa Eastern and Southern  1999  Africa Eastern and Southern, 1999
# 36   Africa Eastern and Southern  2000  Africa Eastern and Southern, 2000
# 37   Africa Eastern and Southern  2001  Africa Eastern and Southern, 2001
# 38   Africa Eastern and Southern  2002  Africa Eastern and Southern, 2002
# 39   Africa Eastern and Southern  2003  Africa Eastern and Southern, 2003
# 40   Africa Eastern and Southern  2004  Africa Eastern and Southern, 2004
# 41   Africa Eastern and Southern  2005  Africa Eastern and Southern, 2005
# 42   Africa Eastern and Southern  2006  Africa Eastern and Southern, 2006
# 43   Africa Eastern and Southern  2007  Africa Eastern and Southern, 2007
# 44   Africa Eastern and Southern  2008  Africa Eastern and Southern, 2008
# 45   Africa Eastern and Southern  2009  Africa Eastern and Southern, 2009
# 46   Africa Eastern and Southern  2010  Africa Eastern and Southern, 2010
# 47   Africa Eastern and Southern  2011  Africa Eastern and Southern, 2011
# 48   Africa Eastern and Southern  2012  Africa Eastern and Southern, 2012
# 49   Africa Eastern and Southern  2013  Africa Eastern and Southern, 2013
# 50   Africa Eastern and Southern  2014  Africa Eastern and Southern, 2014
# 51   Africa Eastern and Southern  2015  Africa Eastern and Southern, 2015
# 260                    Argentina  1990                    Argentina, 1990
# 261                    Argentina  1991                    Argentina, 1991
# 262                    Argentina  1992                    Argentina, 1992
# 263                    Argentina  1993                    Argentina, 1993
#
#      %_energy_nuclear
# 26           3.866791
# 27           4.140830
# 28           4.250650
# 29           3.201404
# 30           4.149434
# 31           4.679020
# 32           4.603900
# 33           4.768023
# 34           5.108086
# 35           4.816205
# 36           4.681261
# 37           3.780810
# 38           4.026182
# 39           4.069472
# 40           4.092130
# 41           3.396172
# 42           2.903757
# 43           3.153268
# 44           3.672838
# 45           3.665910
# 46           3.306398
# 47           3.608979
# 48           3.212862
# 49           3.732574
# 50           3.580038
# 51                NaN
# 260         14.349626
# 261         14.463943
# 262         12.671570
# 263         12.586073

# %%
nuc_weight.isnull().sum()
# Out:
# country              0
# year                 0
# combined key         0
# %_energy_nuclear    27
# dtype: int64

# %%
#created a weighted average column to use for final missing values
nuc_weight['Weighted_Avg'] = nuc_weight.groupby('country')['%_energy_nuclear'].transform(lambda x: x.fillna(x.mean()))
# Out:
# C:\Users\jacob\AppData\Local\Temp\ipykernel_9004\1028736024.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nuc_weight['Weighted_Avg'] = nuc_weight.groupby('country')['%_energy_nuclear'].transform(lambda x: x.fillna(x.mean()))

# %%
nuc_weight.head(150)
# Out:
#                          country  year                       combined key  \
# 26   Africa Eastern and Southern  1990  Africa Eastern and Southern, 1990
# 27   Africa Eastern and Southern  1991  Africa Eastern and Southern, 1991
# 28   Africa Eastern and Southern  1992  Africa Eastern and Southern, 1992
# 29   Africa Eastern and Southern  1993  Africa Eastern and Southern, 1993
# 30   Africa Eastern and Southern  1994  Africa Eastern and Southern, 1994
# ..                           ...   ...                                ...
# 847                     Bulgaria  2005                     Bulgaria, 2005
# 848                     Bulgaria  2006                     Bulgaria, 2006
# 849                     Bulgaria  2007                     Bulgaria, 2007
# 850                     Bulgaria  2008                     Bulgaria, 2008
# 851                     Bulgaria  2009                     Bulgaria, 2009
#
#      %_energy_nuclear  Weighted_Avg
# 26           3.866791      3.866791
# 27           4.140830      4.140830
# 28           4.250650      4.250650
# 29           3.201404      3.201404
# 30           4.149434      4.149434
# ..                ...           ...
# 847         42.420176     42.420176
# 848         42.839875     42.839875
# 849         34.103454     34.103454
# 850         35.360219     35.360219
# 851         35.997263     35.997263
#
# [150 rows x 5 columns]

# %%
27 + 2255
# Out:
# 2282

# %%
nuc_weight.tail(20)
# Out:
#      country  year combined key  %_energy_nuclear  Weighted_Avg
# 6818   World  1996  World, 1996         17.583602     17.583602
# 6819   World  1997  World, 1997         17.046995     17.046995
# 6820   World  1998  World, 1998         16.975507     16.975507
# 6821   World  1999  World, 1999         17.084883     17.084883
# 6822   World  2000  World, 2000         16.703651     16.703651
# 6823   World  2001  World, 2001         16.877983     16.877983
# 6824   World  2002  World, 2002         16.384221     16.384221
# 6825   World  2003  World, 2003         15.656159     15.656159
# 6826   World  2004  World, 2004         15.551745     15.551745
# 6827   World  2005  World, 2005         15.071328     15.071328
# 6828   World  2006  World, 2006         14.632634     14.632634
# 6829   World  2007  World, 2007         13.662399     13.662399
# 6830   World  2008  World, 2008         13.475271     13.475271
# 6831   World  2009  World, 2009         13.344125     13.344125
# 6832   World  2010  World, 2010         12.786946     12.786946
# 6833   World  2011  World, 2011         11.604178     11.604178
# 6834   World  2012  World, 2012         10.811500     10.811500
# 6835   World  2013  World, 2013         10.580147     10.580147
# 6836   World  2014  World, 2014         10.601444     10.601444
# 6837   World  2015  World, 2015          8.113442      8.113442

# %%
#drop %_energy_nuclear column with missing values
nuc_weight_imputed = nuc_weight.drop(columns = ['%_energy_nuclear'])

# %%
nuc_weight_imputed.head()
# Out:
#                         country  year                       combined key  \
# 26  Africa Eastern and Southern  1990  Africa Eastern and Southern, 1990
# 27  Africa Eastern and Southern  1991  Africa Eastern and Southern, 1991
# 28  Africa Eastern and Southern  1992  Africa Eastern and Southern, 1992
# 29  Africa Eastern and Southern  1993  Africa Eastern and Southern, 1993
# 30  Africa Eastern and Southern  1994  Africa Eastern and Southern, 1994
#
#     Weighted_Avg
# 26      3.866791
# 27      4.140830
# 28      4.250650
# 29      3.201404
# 30      4.149434

# %%
#change weighted_avgerage column to new %_energy_nuclear column
nuc_weight_imputed_2 = nuc_weight_imputed.rename(columns = {'Weighted_Avg' : '%_energy_nuclear'})

# %%
nuc_weight_imputed_2.head()
# Out:
#                         country  year                       combined key  \
# 26  Africa Eastern and Southern  1990  Africa Eastern and Southern, 1990
# 27  Africa Eastern and Southern  1991  Africa Eastern and Southern, 1991
# 28  Africa Eastern and Southern  1992  Africa Eastern and Southern, 1992
# 29  Africa Eastern and Southern  1993  Africa Eastern and Southern, 1993
# 30  Africa Eastern and Southern  1994  Africa Eastern and Southern, 1994
#
#     %_energy_nuclear
# 26          3.866791
# 27          4.140830
# 28          4.250650
# 29          3.201404
# 30          4.149434

# %%
#check for missing values
nuc_weight_imputed_2.isnull().sum()
# Out:
# country             0
# year                0
# combined key        0
# %_energy_nuclear    0
# dtype: int64

# %%
#concate list nuc_weight_imputed on nuc_zero_imputed
nuc_concated = pd.concat([nuc_weight_imputed_2,nuc_zero_imputed], ignore_index = True)

# %%
#check shape
nuc_concated.shape
# Out:
# (6916, 4)

# %%
#check for missing values
nuc_concated.isnull().sum()
# Out:
# country             0
# year                0
# combined key        0
# %_energy_nuclear    0
# dtype: int64

# %%
#check data
nuc_concated.head(150)
# Out:
#                          country  year                       combined key  \
# 0    Africa Eastern and Southern  1990  Africa Eastern and Southern, 1990
# 1    Africa Eastern and Southern  1991  Africa Eastern and Southern, 1991
# 2    Africa Eastern and Southern  1992  Africa Eastern and Southern, 1992
# 3    Africa Eastern and Southern  1993  Africa Eastern and Southern, 1993
# 4    Africa Eastern and Southern  1994  Africa Eastern and Southern, 1994
# ..                           ...   ...                                ...
# 145                     Bulgaria  2005                     Bulgaria, 2005
# 146                     Bulgaria  2006                     Bulgaria, 2006
# 147                     Bulgaria  2007                     Bulgaria, 2007
# 148                     Bulgaria  2008                     Bulgaria, 2008
# 149                     Bulgaria  2009                     Bulgaria, 2009
#
#      %_energy_nuclear
# 0            3.866791
# 1            4.140830
# 2            4.250650
# 3            3.201404
# 4            4.149434
# ..                ...
# 145         42.420176
# 146         42.839875
# 147         34.103454
# 148         35.360219
# 149         35.997263
#
# [150 rows x 4 columns]

# %%
#sort data aphabetically and then by year
nuc_sorted = nuc_concated.sort_values(by = ['country', 'year']).reset_index(drop = True)

# %%
#check output
nuc_sorted
# Out:
#           country  year       combined key  %_energy_nuclear
# 0     Afghanistan  1990  Afghanistan, 1990               0.0
# 1     Afghanistan  1991  Afghanistan, 1991               0.0
# 2     Afghanistan  1992  Afghanistan, 1992               0.0
# 3     Afghanistan  1993  Afghanistan, 1993               0.0
# 4     Afghanistan  1994  Afghanistan, 1994               0.0
# ...           ...   ...                ...               ...
# 6911     Zimbabwe  2011     Zimbabwe, 2011               0.0
# 6912     Zimbabwe  2012     Zimbabwe, 2012               0.0
# 6913     Zimbabwe  2013     Zimbabwe, 2013               0.0
# 6914     Zimbabwe  2014     Zimbabwe, 2014               0.0
# 6915     Zimbabwe  2015     Zimbabwe, 2015               0.0
#
# [6916 rows x 4 columns]

# %%
nuc_sorted.isnull().sum()
# Out:
# country             0
# year                0
# combined key        0
# %_energy_nuclear    0
# dtype: int64

# %%
#check descriptive stats
nuc_sorted.describe()
# Out:
#               year  %_energy_nuclear
# count  6916.000000       6916.000000
# mean   2002.500000          4.171182
# std       7.500542         11.571857
# min    1990.000000          0.000000
# 25%    1996.000000          0.000000
# 50%    2002.500000          0.000000
# 75%    2009.000000          0.000000
# max    2015.000000         87.986221

# %%
nuc_sorted.shape
# Out:
# (6916, 4)

# %%
#export wrangled energy nuclear data
nuc_sorted.to_csv(os.path.join(path, '02 data', 'prepared data', 'energy_from_nuclear_wrangled.csv'))
