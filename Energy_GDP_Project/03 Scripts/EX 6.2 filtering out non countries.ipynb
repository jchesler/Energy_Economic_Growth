# %%
#import libriaries
import pandas as pd
import numpy as np
import os

# %%
#create path
path = r'C:\Users\jacob\Documents\Data Analytics\Data Immersion\Achievement 6\Energy_GDP_Project'

# %%
#import data
df = pd.read_csv(os.path.join(path, '02 data','prepared data', 'energy_gdp_merged_inner.csv'))

# %%
#check output
df.head()
# Out:
#        country  year       combined_key   ea_%_pop  %_energy_nuclear  \
# 0  Afghanistan  2000  Afghanistan, 2000   4.446891               0.0
# 1  Afghanistan  2001  Afghanistan, 2001   9.294527               0.0
# 2  Afghanistan  2002  Afghanistan, 2002  14.133616               0.0
# 3  Afghanistan  2003  Afghanistan, 2003  18.971165               0.0
# 4  Afghanistan  2004  Afghanistan, 2004  23.814182               0.0
#
#    %_energy_renewables  %_energy_fossil_fuels         gdp
# 0                  0.0                    0.0  183.532775
# 1                  0.0                    0.0  183.532775
# 2                  0.0                    0.0  183.532775
# 3                  0.0                    0.0  200.462376
# 4                  0.0                    0.0  221.657662

# %%
df['country'].nunique()
# Out:
# 261

# %%
#create a list of all the unique countries in the country column
unique_countries = df['country'].unique().tolist()

# %%
#check output of the list
unique_countries
# Out:
# ['Afghanistan',
#  'Africa Eastern and Southern',
#  'Africa Western and Central',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Arab World',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Caribbean small states',
#  'Cayman Islands',
#  'Central African Republic',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czechia',
#  'Denmark',
#  'Djibouti',
# ...

# %%
#create a list of only countries from the country column
countries = ['Afghanistan',
 'Albania',
 'Algeria',
 'Andorra',
 'Angola',
 'Antigua and Barbuda',
 'Argentina',
 'Armenia',
 'Aruba',
 'Australia',
 'Austria',
 'Azerbaijan',
 'Bahamas, The',
 'Bahrain',
 'Bangladesh',
 'Barbados',
 'Belarus',
 'Belgium',
 'Belize',
 'Benin',
 'Bermuda',
 'Bhutan',
 'Bolivia',
 'Bosnia and Herzegovina',
 'Botswana',
 'Brazil',
 'Brunei Darussalam',
 'Bulgaria',
 'Burkina Faso',
 'Burundi',
 'Cabo Verde',
 'Cambodia',
 'Cameroon',
 'Canada',
 'Cayman Islands',
 'Chad',
 'Channel Islands',
 'Chile',
 'China',
 'Colombia',
 'Comoros',
 'Congo, Dem. Rep.',
 'Congo, Rep.',
 'Costa Rica',
 "Cote d'Ivoire",
 'Croatia',
 'Cuba',
 'Curacao',
 'Cyprus',
 'Czechia',
 'Denmark',
 'Djibouti',
 'Dominica',
 'Dominican Republic',
 'Ecuador',
 'Egypt, Arab Rep.',
 'El Salvador',
 'Equatorial Guinea',
 'Eritrea',
 'Estonia',
 'Eswatini',
 'Ethiopia',
 'Faroe Islands',
 'Fiji',
 'Finland',
 'France',
 'French Polynesia',
 'Gabon',
 'Gambia, The',
 'Georgia',
 'Germany',
 'Ghana',
 'Greece',
 'Greenland',
 'Grenada',
 'Guam',
 'Guatemala',
 'Guinea',
 'Guinea-Bissau',
 'Guyana',
 'Haiti',
 'Honduras',
 'Hong Kong SAR, China',
 'Hungary',
 'Iceland',
 'India',
 'Indonesia',
 'Iran, Islamic Rep.',
 'Iraq',
 'Ireland',
 'Isle of Man',
 'Israel',
 'Italy',
 'Jamaica',
 'Japan',
 'Jordan',
 'Kazakhstan',
 'Kenya',
 'Kiribati',
 'Korea, Rep.',
 'Kosovo',
 'Kuwait',
 'Kyrgyz Republic',
 'Lao PDR',
 'Latvia',
 'Lebanon',
 'Lesotho',
 'Liberia',
 'Libya',
 'Liechtenstein',
 'Lithuania',
 'Luxembourg',
 'Macao SAR, China',
 'Madagascar',
 'Malawi',
 'Malaysia',
 'Maldives',
 'Mali',
 'Malta',
 'Marshall Islands',
 'Mauritania',
 'Mauritius',
 'Mexico',
 'Micronesia, Fed. Sts.',
 'Moldova',
 'Monaco',
 'Mongolia',
 'Montenegro',
 'Morocco',
 'Mozambique',
 'Myanmar',
 'Namibia',
 'Nauru',
 'Nepal',
 'Netherlands',
 'New Caledonia',
 'New Zealand',
 'Nicaragua',
 'Niger',
 'Nigeria',
 'North Macedonia',
 'Northern Mariana Islands',
 'Norway',
 'Oman',
 'Pakistan',
 'Palau',
 'Panama',
 'Papua New Guinea',
 'Paraguay',
 'Peru',
 'Philippines',
 'Poland',
 'Portugal',
 'Puerto Rico',
 'Qatar',
 'Romania',
 'Russian Federation',
 'Rwanda',
 'Samoa',
 'San Marino',
 'Sao Tome and Principe',
 'Saudi Arabia',
 'Senegal',
 'Serbia',
 'Seychelles',
 'Sierra Leone',
 'Singapore',
 'Sint Maarten (Dutch part)',
 'Slovak Republic',
 'Slovenia',
 'Solomon Islands',
 'Somalia',
 'South Sudan',
 'Spain',
 'Sri Lanka',
 'St. Kitts and Nevis',
 'St. Lucia',
 'St. Martin (French part)',
 'St. Vincent and the Grenadines',
 'Sudan',
 'Suriname',
 'Sweden',
 'Switzerland',
 'Syrian Arab Republic',
 'Tajikistan',
 'Tanzania',
 'Thailand',
 'Timor-Leste',
 'Togo',
 'Tonga',
 'Trinidad and Tobago',
 'Tunisia',
 'Turkiye',
 'Turkmenistan',
 'Turks and Caicos Islands',
 'Tuvalu',
 'Uganda',
 'Ukraine',
 'United Arab Emirates',
 'United Kingdom',
 'United States',
 'Uruguay',
 'Uzbekistan',
 'Vanuatu',
 'Venezuela, RB',
 'Viet Nam',
 'Virgin Islands (U.S.)',
 'West Bank and Gaza',
 'World',
 'Yemen, Rep.',
 'Zambia',
 'Zimbabwe']

# %%
countries
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cayman Islands',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czechia',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt, Arab Rep.',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
# ...

# %%
#create a list only groups (i.e. continent or region) from country column
groupings = ['Africa Eastern and Southern',
 'Africa Western and Central',
 'Arab World',
'Caribbean small states',
 'Central African Republic',
 'Central Europe and the Baltics',
 'Early-demographic dividend',
 'East Asia & Pacific',
 'East Asia & Pacific (excluding high income)',
 'East Asia & Pacific (IDA & IBRD countries)',
 'Euro area',
 'Europe & Central Asia',
 'Europe & Central Asia (excluding high income)',
 'Europe & Central Asia (IDA & IBRD countries)',
 'European Union',
'Fragile and conflict affected situations',
 'Heavily indebted poor countries (HIPC)',
 'High income',
 'IBRD only',
     'IDA & IBRD total',
 'IDA blend',
 'IDA only',
 'IDA total',
 'Late-demographic dividend',
 'Latin America & Caribbean',
 'Latin America & Caribbean (excluding high income)',
 'Latin America & the Caribbean (IDA & IBRD countries)',
 'Least developed countries: UN classification',
     'Low & middle income',
 'Low income',
 'Lower middle income',
     'Middle East & North Africa',
 'Middle East & North Africa (excluding high income)',
 'Middle East & North Africa (IDA & IBRD countries)',
 'Middle income',
'North America',
 'OECD members',
     'Other small states',
 'Pacific island small states',
'Post-demographic dividend',
 'Pre-demographic dividend',
     'Small states',
        
        
 'South Africa',
 'South Asia',
 'South Asia (IDA & IBRD)',
'Sub-Saharan Africa',
 'Sub-Saharan Africa (excluding high income)',
 'Sub-Saharan Africa (IDA & IBRD countries)',
 'Upper middle income']

# %%
#check the groupings list
groupings
# Out:
# ['Africa Eastern and Southern',
#  'Africa Western and Central',
#  'Arab World',
#  'Caribbean small states',
#  'Central African Republic',
#  'Central Europe and the Baltics',
#  'Early-demographic dividend',
#  'East Asia & Pacific',
#  'East Asia & Pacific (excluding high income)',
#  'East Asia & Pacific (IDA & IBRD countries)',
#  'Euro area',
#  'Europe & Central Asia',
#  'Europe & Central Asia (excluding high income)',
#  'Europe & Central Asia (IDA & IBRD countries)',
#  'European Union',
#  'Fragile and conflict affected situations',
#  'Heavily indebted poor countries (HIPC)',
#  'High income',
#  'IBRD only',
#  'IDA & IBRD total',
#  'IDA blend',
#  'IDA only',
#  'IDA total',
#  'Late-demographic dividend',
#  'Latin America & Caribbean',
#  'Latin America & Caribbean (excluding high income)',
#  'Latin America & the Caribbean (IDA & IBRD countries)',
#  'Least developed countries: UN classification',
#  'Low & middle income',
#  'Low income',
# ...

# %%
#create a new dataframe that only uses countries from the countries list
df_countries = df[df['country'].isin(countries)]

# %%
#check the unique names in the country column of the new df_countries dataframe
df_countries['country'].nunique()
# Out:
# 212

# %%
#create a new dataframe that only uses countries from the groupings list
df_groupings = df[df['country'].isin(groupings)]

# %%
#check the unique names in the country column of the new df_groupings dataframe
df_groupings['country'].nunique()
# Out:
# 49

# %%
212+49
# Out:
# 261

# %% [markdown]
# 212 plus 49 = 261 unique countires which matches the original shape of the dataframe, so i know that i didn't miss any countries when creating the lists

# %%
#check the output of df_countries
df_countries.head()
# Out:
#        country  year       combined_key   ea_%_pop  %_energy_nuclear  \
# 0  Afghanistan  2000  Afghanistan, 2000   4.446891               0.0
# 1  Afghanistan  2001  Afghanistan, 2001   9.294527               0.0
# 2  Afghanistan  2002  Afghanistan, 2002  14.133616               0.0
# 3  Afghanistan  2003  Afghanistan, 2003  18.971165               0.0
# 4  Afghanistan  2004  Afghanistan, 2004  23.814182               0.0
#
#    %_energy_renewables  %_energy_fossil_fuels         gdp
# 0                  0.0                    0.0  183.532775
# 1                  0.0                    0.0  183.532775
# 2                  0.0                    0.0  183.532775
# 3                  0.0                    0.0  200.462376
# 4                  0.0                    0.0  221.657662

# %%
#check the shape of df_countries
df_countries.shape
# Out:
# (4730, 8)

# %%
#export df_countries to a csv titled 'energy_gdp_merged_inner_countries.csv'
df_countries.to_csv(os.path.join(path, '02 data', 'prepared data', 'energy_gdp_merged_inner_countries.csv'), index = False)

# %%
#export df_groupings to csv title 'energy_gdp_merged_inner_groupings.csv'
df_groupings.to_csv(os.path.join(path, '02 data', 'prepared data', 'energy_gdp_merged_inner_groupings.csv'), index = False)
