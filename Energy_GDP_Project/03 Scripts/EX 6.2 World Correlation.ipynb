# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
#create path
path = r'C:\Users\jacob\Documents\Data Analytics\Data Immersion\Achievement 6\Energy_GDP_Project'

# %%
#import merged inner data
df = pd.read_csv(os.path.join(path, '02 data', 'prepared data', 'energy_gdp_merged_inner_countries.csv'))

# %%
df.head()
# Out:
#        country  year       combined_key   ea_%_pop  %_energy_nuclear  \
# 0  Afghanistan  2000  Afghanistan, 2000   4.446891               0.0
# 1  Afghanistan  2001  Afghanistan, 2001   9.294527               0.0
# 2  Afghanistan  2002  Afghanistan, 2002  14.133616               0.0
# 3  Afghanistan  2003  Afghanistan, 2003  18.971165               0.0
# 4  Afghanistan  2004  Afghanistan, 2004  23.814182               0.0
#
#    %_energy_renewables  %_energy_fossil_fuels         gdp
# 0                  0.0                    0.0  183.532775
# 1                  0.0                    0.0  183.532775
# 2                  0.0                    0.0  183.532775
# 3                  0.0                    0.0  200.462376
# 4                  0.0                    0.0  221.657662

# %%
df_world = df.loc[df['country'] == 'World']

# %%
df_world.head(20)
# Out:
#      country  year combined_key   ea_%_pop  %_energy_nuclear  \
# 4638   World  1998  World, 1998  73.350250         16.975507
# 4639   World  1999  World, 1999  74.657854         17.084883
# 4640   World  2000  World, 2000  78.364376         16.703651
# 4641   World  2001  World, 2001  78.845438         16.877983
# 4642   World  2002  World, 2002  79.230326         16.384221
# 4643   World  2003  World, 2003  80.093097         15.656159
# 4644   World  2004  World, 2004  80.063555         15.551745
# 4645   World  2005  World, 2005  80.835949         15.071328
# 4646   World  2006  World, 2006  81.468864         14.632634
# 4647   World  2007  World, 2007  82.095816         13.662399
# 4648   World  2008  World, 2008  82.788799         13.475271
# 4649   World  2009  World, 2009  82.983962         13.344125
# 4650   World  2010  World, 2010  83.566033         12.786946
# 4651   World  2011  World, 2011  84.624339         11.604178
# ...

# %%
df_world.plot.scatter(x = 'ea_%_pop', y = 'gdp')
plt.title('World GDP vs Electricity Access')
plt.xlabel('Electricity Access')
plt.ylabel('GDP per Capita')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df_us = df.loc[df['country'] == 'United States']

# %%
df_us.plot.scatter(x = 'ea_%_pop', y = 'gdp')
plt.title('United States GDP vs Electricity Access')
plt.xlabel('Electricity Access')
plt.ylabel('GDP per Capita')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df_sub = df[['ea_%_pop', 'gdp']]

# %%
df_sub.corr()
# Out:
#           ea_%_pop       gdp
# ea_%_pop  1.000000  0.389219
# gdp       0.389219  1.000000

# %%
df_world_sub = df_world[['gdp', 'ea_%_pop', '%_energy_fossil_fuels', '%_energy_renewables', '%_energy_nuclear']]

# %%
df_world_sub.corr()
# Out:
#                             gdp  ea_%_pop  %_energy_fossil_fuels  \
# gdp                    1.000000  0.920472               0.762997
# ea_%_pop               0.920472  1.000000               0.788393
# %_energy_fossil_fuels  0.762997  0.788393               1.000000
# %_energy_renewables    0.884659  0.873536               0.460512
# %_energy_nuclear      -0.939147 -0.922653              -0.617964
#
#                        %_energy_renewables  %_energy_nuclear
# gdp                               0.884659         -0.939147
# ea_%_pop                          0.873536         -0.922653
# %_energy_fossil_fuels             0.460512         -0.617964
# %_energy_renewables               1.000000         -0.972717
# %_energy_nuclear                 -0.972717          1.000000

# %%
df.tail()
# Out:
#        country  year    combined_key   ea_%_pop  %_energy_nuclear  \
# 4725  Zimbabwe  2011  Zimbabwe, 2011  36.900000               0.0
# 4726  Zimbabwe  2012  Zimbabwe, 2012  44.000000               0.0
# 4727  Zimbabwe  2013  Zimbabwe, 2013  40.644161               0.0
# 4728  Zimbabwe  2014  Zimbabwe, 2014  32.300000               0.0
# 4729  Zimbabwe  2015  Zimbabwe, 2015  33.700000               0.0
#
#       %_energy_renewables  %_energy_fossil_fuels          gdp
# 4725             1.421441              42.144097  1082.615773
# 4726             1.825492              39.606650  1290.193957
# 4727             1.734587              46.060606  1408.367810
# 4728             1.436266              44.394574  1407.034291
# 4729             1.328664              47.275724  1410.329173

# %%
df_zim = df.loc[df['country'] == 'Zimbabwe']

# %%
df_zim_sub = df_zim[['gdp', 'ea_%_pop', '%_energy_fossil_fuels', '%_energy_renewables', '%_energy_nuclear']]

# %%
df_zim_sub.corr()
# Out:
#                             gdp  ea_%_pop  %_energy_fossil_fuels  \
# gdp                    1.000000  0.233821              -0.083938
# ea_%_pop               0.233821  1.000000              -0.720790
# %_energy_fossil_fuels -0.083938 -0.720790               1.000000
# %_energy_renewables    0.703846  0.600604              -0.644474
# %_energy_nuclear            NaN       NaN                    NaN
#
#                        %_energy_renewables  %_energy_nuclear
# gdp                               0.703846               NaN
# ea_%_pop                          0.600604               NaN
# %_energy_fossil_fuels            -0.644474               NaN
# %_energy_renewables               1.000000               NaN
# %_energy_nuclear                       NaN               NaN

# %%
df_us_sub = df_us[['gdp', 'ea_%_pop', '%_energy_fossil_fuels', '%_energy_renewables', '%_energy_nuclear']]

# %%
df_us_sub.corr()
# Out:
#                             gdp  ea_%_pop  %_energy_fossil_fuels  \
# gdp                    1.000000       NaN              -0.175368
# ea_%_pop                    NaN       NaN                    NaN
# %_energy_fossil_fuels -0.175368       NaN               1.000000
# %_energy_renewables    0.759751       NaN              -0.711127
# %_energy_nuclear      -0.258079       NaN               0.107112
#
#                        %_energy_renewables  %_energy_nuclear
# gdp                               0.759751         -0.258079
# ea_%_pop                               NaN               NaN
# %_energy_fossil_fuels            -0.711127          0.107112
# %_energy_renewables               1.000000         -0.288639
# %_energy_nuclear                 -0.288639          1.000000

# %%
df_us.head(70)
# Out:
#             country  year         combined_key  ea_%_pop  %_energy_nuclear  \
# 4458  United States  1990  United States, 1990     100.0         19.095370
# 4459  United States  1991  United States, 1991     100.0         19.951488
# 4460  United States  1992  United States, 1992     100.0         20.056583
# 4461  United States  1993  United States, 1993     100.0         19.076609
# 4462  United States  1994  United States, 1994     100.0         19.668408
# 4463  United States  1995  United States, 1995     100.0         20.059893
# 4464  United States  1996  United States, 1996     100.0         19.588173
# 4465  United States  1997  United States, 1997     100.0         18.146053
# 4466  United States  1998  United States, 1998     100.0         18.770489
# 4467  United States  1999  United States, 1999     100.0         19.924706
# 4468  United States  2000  United States, 2000     100.0         19.814724
# ...
